# %%
# !uv pip install sec-edgar-downloader
# Out:
# Audited 1 package in 1ms

# %%
from sec_edgar_downloader import Downloader

# %%
dl = Downloader("Noel Jacob", "noeljacob91@gmail.com", "./sec-edgar-downloader-data")

dl.get("10-K", "AAPL")
# Out:
# 30
