# %% [markdown]
# # Booking.com Kerala Hotels & Reviews Scraper (Scrapy)
#
# This notebook scrapes hotels and reviews from Booking.com Kerala region using **Scrapy**.
#
# **Goal**: Collect 250 hotels with at least 10 reviews each.
#
# **Features**:
#
# - Scrapy-based async scraping (fast & efficient)
# - Progress checkpoints for recovery
# - Detailed status outputs
# - CSV export matching the model format
# - Anti-bot handling with rotating headers

# %% [markdown]
# ## 1. Install Required Libraries

# %%
# Install required packages
# !uv pip install patchright pandas lxml tqdm nest_asyncio
# Out:
# Audited 5 packages in 2ms

# %% [markdown]
# ## 2. Import Libraries and Setup

# %%
import asyncio
import nest_asyncio

nest_asyncio.apply()

from patchright.async_api import async_playwright
from bs4 import BeautifulSoup
import time
import json
import re
from datetime import datetime
from pathlib import Path
from urllib.parse import urljoin, urlencode
import pandas as pd
from tqdm.notebook import tqdm

# Configuration
TARGET_HOTELS = 250
MIN_REVIEWS_PER_HOTEL = 10
CHECKPOINT_FILE = "scraping_checkpoint.json"
OUTPUT_CSV = "kerala_hotels_reviews.csv"

# Global storage
scraped_hotels = []
scraped_reviews = []
browser = None
context = None
page = None

print("✓ Libraries imported successfully (using Patchright - undetected)")
print(f"Target: {TARGET_HOTELS} hotels with {MIN_REVIEWS_PER_HOTEL}+ reviews each")
# Out:
# ✓ Libraries imported successfully (using Patchright - undetected)
# Target: 250 hotels with 10+ reviews each

# %% [markdown]
# ## 3. Helper Functions

# %%
def save_checkpoint(hotels, reviews, filename=CHECKPOINT_FILE):
    """Save progress to checkpoint file"""
    data = {
        "hotels": hotels,
        "reviews": reviews,
        "timestamp": datetime.now().isoformat(),
    }
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(data, f, indent=2, ensure_ascii=False)
    print(f"💾 Checkpoint saved: {len(hotels)} hotels, {len(reviews)} reviews")


def load_checkpoint(filename=CHECKPOINT_FILE):
    """Load progress from checkpoint file"""
    if Path(filename).exists():
        with open(filename, "r", encoding="utf-8") as f:
            data = json.load(f)
        print(
            f"📂 Loaded checkpoint: {len(data.get('hotels', []))} hotels, {len(data.get('reviews', []))} reviews"
        )
        return data.get("hotels", []), data.get("reviews", [])
    return [], []


def clean_text(text):
    """Clean and normalize text"""
    if not text:
        return ""
    return re.sub(r"\s+", " ", text.strip())


print("✓ Helper functions defined")
# Out:
# ✓ Helper functions defined

# %% [markdown]
# ## 4. Initialize Browser
#
# Start Playwright browser (visible mode for debugging).

# %%
async def init_browser():
    """Initialize Patchright browser with stealth settings"""
    global browser, context, page

    playwright = await async_playwright().start()

    # Launch with best practices for undetected browsing
    # Using a unique user data directory to avoid conflicts with running Chrome
    import tempfile
    import os

    # Create a unique temp directory for this session
    temp_dir = tempfile.mkdtemp(prefix="booking_scraper_")

    context = await playwright.chromium.launch_persistent_context(
        user_data_dir=temp_dir,
        channel="chrome",  # Use "chrome" if you have Chrome installed
        executable_path="/home/noel/.local/bin/chrome",  # Your Chrome path
        headless=False,
        no_viewport=True,
        # Don't add custom user_agent - let Patchright handle it
    )

    page = context.pages[0] if context.pages else await context.new_page()
    browser = playwright

    print(f"✓ Patchright browser initialized (stealth mode)")
    print(f"  Using temp dir: {temp_dir}")
    return page


# Initialize browser
page = asyncio.get_event_loop().run_until_complete(init_browser())
print("✓ Ready to scrape")
# Out:
# ✓ Patchright browser initialized (stealth mode)
#   Using temp dir: /tmp/booking_scraper___iw1f43
# ✓ Ready to scrape

# %% [markdown]
# ## 5. Scrape Hotel List
#
# Collect hotels from Kerala region search pages.

# %%
async def scrape_hotels_async(max_hotels=TARGET_HOTELS):
    """Scrape hotel list using Playwright"""
    hotels = []
    offset = 0

    print(f"🏨 Collecting up to {max_hotels} hotels...")

    while len(hotels) < max_hotels:
        url = f"https://www.booking.com/searchresults.html?dest_id=3476&dest_type=region&offset={offset}"
        print(f"\n📄 Page {offset // 25 + 1} (offset={offset})...")

        try:
            await page.goto(url, wait_until="networkidle", timeout=60000)
            await asyncio.sleep(3)

            # Handle popups
            try:
                await page.click(
                    'button[aria-label="Dismiss sign-in info."]', timeout=3000
                )
            except:
                pass

            # Scroll to load all content
            for _ in range(3):
                await page.evaluate("window.scrollTo(0, document.body.scrollHeight)")
                await asyncio.sleep(1)

            # Get page content
            html = await page.content()
            soup = BeautifulSoup(html, "lxml")

            # Find hotel cards
            cards = soup.select('div[data-testid="property-card"]')
            if not cards:
                cards = soup.select("[data-hotelid]")

            if not cards:
                print("⚠️ No hotel cards found")
                # Save for debugging
                with open(f"debug_page_{offset}.html", "w") as f:
                    f.write(html[:100000])
                break

            print(f"  Found {len(cards)} hotel cards")
            hotels_added = 0

            for card in cards:
                if len(hotels) >= max_hotels:
                    break

                try:
                    # Hotel name
                    name_elem = card.select_one('div[data-testid="title"]')
                    if not name_elem:
                        name_elem = card.select_one('[data-testid="title-link"]')
                    name = clean_text(name_elem.get_text()) if name_elem else None

                    # Hotel URL
                    link_elem = card.select_one('a[data-testid="title-link"]')
                    if not link_elem:
                        link_elem = card.select_one('a[href*="/hotel/"]')
                    url = link_elem.get("href", "") if link_elem else ""
                    if url and not url.startswith("http"):
                        url = "https://www.booking.com" + url

                    # Star rating
                    star_elem = card.select('[data-testid="rating-stars"] span')
                    stars = len(star_elem) if star_elem else 0
                    star_rating = f"{stars} STAR" if stars > 0 else ""

                    # Overall rating
                    rating_elem = card.select_one(
                        'div[data-testid="review-score"] div:first-child'
                    )
                    overall_rating = ""
                    if rating_elem:
                        match = re.search(r"(\d+\.?\d*)", rating_elem.get_text())
                        if match:
                            overall_rating = match.group(1)

                    # Review count
                    review_elem = card.select_one('div[data-testid="review-score"]')
                    review_count = ""
                    if review_elem:
                        text = review_elem.get_text()
                        match = re.search(r"(\d+[\d,]*)\s*review", text, re.I)
                        if match:
                            review_count = match.group(1).replace(",", "")

                    if name and url:
                        hotels.append(
                            {
                                "name": name,
                                "url": url.split("?")[0],
                                "star_rating": star_rating,
                                "overall_rating": overall_rating,
                                "review_count": review_count,
                            }
                        )
                        hotels_added += 1

                except Exception as e:
                    continue

            print(f"  ✓ Added {hotels_added} hotels (total: {len(hotels)})")

            if hotels_added == 0:
                print("⚠️ No new hotels, stopping")
                break

            offset += 25
            await asyncio.sleep(2)

        except Exception as e:
            print(f"❌ Error: {e}")
            break

    return hotels


# Run hotel collection
scraped_hotels = asyncio.get_event_loop().run_until_complete(
    scrape_hotels_async(TARGET_HOTELS)
)
print(f"\n✅ Collected {len(scraped_hotels)} hotels")

# Save checkpoint
if scraped_hotels:
    save_checkpoint(scraped_hotels, [])
    print(f"💾 Checkpoint saved")
# Out:
# 🏨 Collecting up to 250 hotels...
#
# 📄 Page 1 (offset=0)...
#   Found 69 hotel cards
#   ✓ Added 69 hotels (total: 69)
#
# 📄 Page 2 (offset=25)...
#   Found 69 hotel cards
#   ✓ Added 69 hotels (total: 138)
#
# 📄 Page 3 (offset=50)...
# ❌ Error: Page.goto: Timeout 60000ms exceeded.
# Call log:
#   - navigating to "https://www.booking.com/searchresults.html?dest_id=3476&dest_type=region&offset=50", waiting until "networkidle"
#
#
# ✅ Collected 138 hotels
# 💾 Checkpoint saved: 138 hotels, 0 reviews
# 💾 Checkpoint saved

# %% [markdown]
# ## 6. View Collected Hotels
#
# Check the hotel list before collecting reviews.

# %%
# Load from checkpoint if needed
if not scraped_hotels:
    scraped_hotels, scraped_reviews = load_checkpoint()

if scraped_hotels:
    hotels_df = pd.DataFrame(scraped_hotels)
    print(f"📊 Total hotels: {len(hotels_df)}")
    display(hotels_df.head(15))

    print(f"\n⭐ Star distribution:")
    print(hotels_df["star_rating"].value_counts())
else:
    print("⚠️ No hotels collected. Run cell 5 first.")
# Out:
# 📊 Total hotels: 138
#                                                  name  \
# 0                        Blue Serene Backwater Resort
# 1                                       SylVan Resort
# 2           The Crescent Wayanad Heritage Pool Resort
# 3                              PARK RESIDENCY ARCADIA
# 4   Super Hotel O Thrissur Near Thrissur Medical C...
# 5                                   Hotel Urban Bella
# 6   Nature Valley Farmhouse Resort by Raarees, Mun...
# 7               Royal Plaza Inn by RAK Rooms, Calicut
# 8                      WithInn Hotel - Kannur Airport
# 9   Ushasree Wayanad Premium Pool Resort by VOYE H...
# 10                                 The TeaTree Munnar
# 11                               Thekkady Gavi Suites
# 12                                Kovalam Beach House
# 13                             Pugmarks Jungle Resort
# 14                                      Viraj Retreat
#
#                                                   url star_rating  \
# 0   https://www.booking.com/hotel/in/blue-serene-r...     10 STAR
# 1   https://www.booking.com/hotel/in/sylvan-resort...
# 2   https://www.booking.com/hotel/in/the-cresent-w...
# 3   https://www.booking.com/hotel/in/park-residenc...      8 STAR
# 4   https://www.booking.com/hotel/in/oyo-flagship-...      6 STAR
# 5   https://www.booking.com/hotel/in/urban-bella.e...      6 STAR
# 6   https://www.booking.com/hotel/in/tamshikanya-i...      8 STAR
# 7   https://www.booking.com/hotel/in/royal-plaza-i...      6 STAR
# 8   https://www.booking.com/hotel/in/withinn-kannu...      6 STAR
# 9   https://www.booking.com/hotel/in/ushashree-way...
# 10  https://www.booking.com/hotel/in/the-teatree-m...
# 11  https://www.booking.com/hotel/in/thekkady-gavi...      6 STAR
# 12  https://www.booking.com/hotel/in/kovalam-beach...
# 13  https://www.booking.com/hotel/in/pugmarks-jung...
# 14  https://www.booking.com/hotel/in/viraj-retreat...      8 STAR
#
#    overall_rating review_count
# 0             7.3          100
# 1             9.2          159
# 2             7.3           25
# 3             8.1          184
# 4             6.5            5
# 5             8.5           39
# 6             8.1           71
# 7             8.4          118
# 8             8.5          135
# 9             8.3           73
# 10            8.7           17
# 11            8.7          103
# 12            8.1          175
# 13            8.8           57
# 14            8.8            8
# ⭐ Star distribution:
# star_rating
#            48
# 8 STAR     34
# 6 STAR     32
# 10 STAR    18
# 4 STAR      6
# Name: count, dtype: int64

# %% [markdown]
# ## 7. Scrape Reviews for Hotels
#
# Visit each hotel and collect reviews.

# %%
async def scrape_reviews_async(hotel, min_reviews=MIN_REVIEWS_PER_HOTEL, debug=False):
    """Scrape reviews for a single hotel"""
    reviews = []
    hotel_name = hotel["name"]

    try:
        # Go to hotel page
        await page.goto(hotel["url"], wait_until="networkidle", timeout=60000)
        await asyncio.sleep(3)

        # Check sold out status
        html = await page.content()
        sold_out = (
            "SOLD OUT"
            if "sold out" in html.lower() or "no availability" in html.lower()
            else "AVAILABLE"
        )
        hotel["sold_out_status"] = sold_out

        # Close any popups
        try:
            await page.click('button[aria-label="Dismiss sign-in info."]', timeout=2000)
        except:
            pass

        # Scroll to reviews section (it's usually lower on the page)
        for i in range(5):
            await page.evaluate(
                f"window.scrollTo(0, document.body.scrollHeight * {0.2 * (i + 1)})"
            )
            await asyncio.sleep(0.5)

        # Wait for page to stabilize
        await asyncio.sleep(2)

        # Click "Read all reviews" button to open reviews modal/section
        try:
            # Use page.click with timeout - it will scroll to element if needed
            await page.click('[data-testid="fr-read-all-reviews"]', timeout=5000)
            if debug:
                print("    ✓ Clicked: fr-read-all-reviews button")
            await asyncio.sleep(3)
        except Exception as e:
            if debug:
                print(f"    ⚠️ Could not click fr-read-all-reviews: {e}")

            # Try alternative selectors
            alt_selectors = [
                'button[data-testid="fr-read-all-reviews"]',
                '[data-testid="review-score-read-all"]',
                'a[href*="#tab-reviews"]',
            ]
            for selector in alt_selectors:
                try:
                    await page.click(selector, timeout=3000)
                    if debug:
                        print(f"    ✓ Clicked alternative: {selector}")
                    await asyncio.sleep(3)
                    break
                except:
                    continue

        # Get updated page content
        html = await page.content()
        soup = BeautifulSoup(html, "lxml")

        # DEBUG: Save HTML
        if debug:
            debug_file = f"debug_hotel_{hotel_name[:20].replace(' ', '_')}.html"
            with open(debug_file, "w", encoding="utf-8") as f:
                f.write(html)
            print(f"    📄 Saved debug HTML to: {debug_file}")

        # Find review cards
        review_cards = soup.select('div[data-testid="review-card"]')

        if debug:
            print(f"    🔍 Found {len(review_cards)} review cards")

        for card in review_cards[:min_reviews]:
            try:
                # Reviewer name - look for the name inside the reviewer section
                reviewer = "Anonymous"
                name_elem = card.select_one("div.b08850ce41.f546354b44")
                if name_elem:
                    reviewer = clean_text(name_elem.get_text())

                # Rating - the score number like "7.0"
                rating = ""
                rating_elem = card.select_one("div.f63b14ab7a")
                if rating_elem:
                    rating = clean_text(rating_elem.get_text())

                # Title - h4[data-testid="review-title"]
                title = ""
                title_elem = card.select_one('h4[data-testid="review-title"]')
                if title_elem:
                    title = clean_text(title_elem.get_text())

                # Get actual user review text (positive + negative combined)
                text_parts = []

                # Positive review text - get the span inside b99b6ef58f div
                pos_container = card.select_one('[data-testid="review-positive-text"]')
                if pos_container:
                    pos_span = pos_container.select_one("div.b99b6ef58f span")
                    if pos_span:
                        text_parts.append(clean_text(pos_span.get_text()))

                # Negative review text - get the span inside b99b6ef58f div
                neg_container = card.select_one('[data-testid="review-negative-text"]')
                if neg_container:
                    neg_span = neg_container.select_one("div.b99b6ef58f span")
                    if neg_span:
                        text_parts.append(clean_text(neg_span.get_text()))

                # Combine all text
                review_text = " ".join(text_parts)[:500] if text_parts else ""

                reviews.append(
                    {
                        "hotel_name": hotel_name,
                        "reviewer_name": reviewer,
                        "rating": rating,
                        "review_title": title,
                        "review_text": review_text,
                        "star_rating": hotel.get("star_rating", ""),
                        "overall_rating": hotel.get("overall_rating", ""),
                        "total_review_count": hotel.get("review_count", ""),
                        "sold_out_status": sold_out,
                    }
                )

                if debug and len(reviews) <= 3:
                    print(
                        f"      Review {len(reviews)}: {reviewer} - {rating} - {title[:30]}..."
                    )
                    print(f"         Text: {review_text[:100]}...")

            except Exception as e:
                if debug:
                    print(f"    Error parsing card: {e}")
                continue

    except Exception as e:
        print(f"  Error: {e}")

    return reviews


print("✓ Review scraping function defined (with scrolling + click)")
# Out:
# ✓ Review scraping function defined (with scrolling + click)

# %% [markdown]
# ## 8. Debug Single Hotel (Test)
#
# Run this to debug review extraction on one hotel. Check the browser while it runs!

# %%
# DEBUG: Test on first hotel with detailed output
# The browser will navigate to the hotel page - watch it!

if scraped_hotels:
    test_hotel = scraped_hotels[0]
    print(f"🧪 Testing on: {test_hotel['name']}")
    print(f"   URL: {test_hotel['url']}")
    print()

    # Run with debug=True
    test_reviews = asyncio.get_event_loop().run_until_complete(
        scrape_reviews_async(test_hotel, min_reviews=10, debug=True)
    )

    print(f"\n📊 Found {len(test_reviews)} reviews")

    if test_reviews:
        for i, r in enumerate(test_reviews[:5]):
            print(f"\n--- Review {i + 1} ---")
            print(f"Reviewer: {r['reviewer_name']}")
            print(f"Rating: {r['rating']}")
            print(f"Title: {r['review_title']}")
            print(f"Text: {r['review_text'][:200]}...")
    else:
        print("\n⚠️ No reviews found. Check the debug HTML file created.")
        print("   Also look at the browser - is the reviews section visible?")
        print("   You may need to scroll down or click something manually.")
else:
    print("⚠️ No hotels loaded. Run cell 10 first.")
# Out:
# 🧪 Testing on: Fort Bridge View
#    URL: https://www.booking.com/hotel/in/fortbridgeview.en-gb.html
#
#     ⚠️ Could not click fr-read-all-reviews: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("[data-testid=\"fr-read-all-reviews\"]")
#     - locator resolved to 2 elements. Proceeding with the first one: JSHandle@<button type="button" data-testid="fr-read-all-reviews" class="de576f5064 b46cd7aad7 d0a01e3d83 c7a901b0e7 bbf83acb81">…</button>
#   - attempting click action
#     2 × waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <div class="bbe73dce14">…</div> from <div class="dc7e768484 a37804931c">…</div> subtree intercepts pointer events
#     - retrying click action
#     - waiting 20ms
#     - waiting for element to be visible, enabled and stable
#     - element is visible, enabled and stable
#     - scrolling into view if needed
#     - done scrolling
#     - <div class="bbe73dce14">…</div> from <div class="dc7e768484 a37804931c">…</div> subtree intercepts pointer events
#   2 × retrying click action
#       - waiting 100ms
#       - waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <div class="fd1bba3c6c c0cc1346bc">…</div> from <div class="dc7e768484 a37804931c">…</div> subtree intercepts pointer events
#   2 × retrying click action
#       - waiting 500ms
#       - waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <h3 class="e7addce19e">Guest reviews</h3> from <div class="dc7e768484 a37804931c">…</div> subtree intercepts pointer events
#     - retrying click action
#       - waiting 500ms
#       - waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <span class="d96a4619c0">Free WiFi </span> from <div class="dc7e768484 a37804931c">…</div> subtree intercepts pointer events
#     - retrying click action
#       - waiting 500ms
#       - waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <div class="fd1bba3c6c c0cc1346bc">…</div> from <div class="dc7e768484 a37804931c">…</div> subtree intercepts pointer events
#     - retrying click action
#       - waiting 500ms
#       - waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <div class="fd1bba3c6c c0cc1346bc">…</div> from <div class="dc7e768484 a37804931c">…</div> subtree intercepts pointer events
#   - retrying click action
#     - waiting 500ms
#
#     ✓ Clicked alternative: [data-testid="review-score-read-all"]
#     📄 Saved debug HTML to: debug_hotel_Fort_Bridge_View.html
#     🔍 Found 10 review cards
#       Review 1: Sarah - 10 - Beautiful hotel with fabulous ...
#          Text: Very beautiful location, fabulous fresh water pool The hotel was situated right under the flight pat...
#       Review 2: Karen - 10 - Exceptional...
#          Text: Loved everything about this property. Beds so comfortable. Monkey madness in the afternoon. Lovely s...
#       Review 3: Jennifer - 9.0 - A great retreat away from Kova...
#          Text: Perfect location, tranquil and beautiful surrounded by trees and wildlife. The massages were the bes...
#
# 📊 Found 10 reviews
#
# --- Review 1 ---
# Reviewer: Sarah
# Rating: 10
# Title: Beautiful hotel with fabulous pool
# Text: Very beautiful location, fabulous fresh water pool The hotel was situated right under the flight path to the airport so it was quite noisy, more noticeable when we were doing yoga. Also no fridges in ...
#
# --- Review 2 ---
# Reviewer: Karen
# Rating: 10
# Title: Exceptional
# Text: Loved everything about this property. Beds so comfortable. Monkey madness in the afternoon. Lovely staff. Great massages. Wonderful yoga...
#
# --- Review 3 ---
# Reviewer: Jennifer
# Rating: 9.0
# Title: A great retreat away from Kovalam, but easy to get to the beach.
# Text: Perfect location, tranquil and beautiful surrounded by trees and wildlife. The massages were the best ever and really delicious food at the restaurant, we ate there most nights....
#
# --- Review 4 ---
# Reviewer: Alison
# Rating: 10
# Title: Time to Relax.
# Text: Set In the most tranquil setting .A little way from the beach ( a short auto rickshaw ride) in the hills overlooking lush vegetation. Peaceful and a totally zen experience.Ayurveda treatments on site,...
#
# --- Review 5 ---
# Reviewer: Varun
# Rating: 8.0
# Title: Very good
# Text: Friendly staff and good location....

# %% [markdown]
# ## 9. Run Full Review Collection
#
# Process all hotels and collect reviews (after debugging works).

# %%
async def collect_all_reviews():
    global scraped_reviews

    if not scraped_hotels:
        print("⚠️ No hotels. Run cell 10 first.")
        return

    # Track processed
    processed = (
        set(r["hotel_name"] for r in scraped_reviews) if scraped_reviews else set()
    )
    all_reviews = list(scraped_reviews) if scraped_reviews else []

    print(f"🚀 Collecting reviews for {len(scraped_hotels)} hotels...")
    print(f"Already processed: {len(processed)}")

    for idx, hotel in enumerate(scraped_hotels):
        if hotel["name"] in processed:
            continue

        print(f"\n🏨 [{idx + 1}/{len(scraped_hotels)}] {hotel['name'][:50]}...")

        reviews = await scrape_reviews_async(hotel, debug=False)
        all_reviews.extend(reviews)
        processed.add(hotel["name"])

        print(f"  ✓ Got {len(reviews)} reviews")

        # Checkpoint every 10 hotels
        if (idx + 1) % 10 == 0:
            save_checkpoint(scraped_hotels, all_reviews)
            print(f"💾 Saved: {len(processed)} hotels, {len(all_reviews)} reviews")

        await asyncio.sleep(2)

    scraped_reviews = all_reviews
    save_checkpoint(scraped_hotels, scraped_reviews)

    print(f"\n✅ Done! {len(scraped_reviews)} reviews from {len(processed)} hotels")


# Run collection
asyncio.get_event_loop().run_until_complete(collect_all_reviews())
# Out:
# 🚀 Collecting reviews for 138 hotels...
# Already processed: 0
#
# 🏨 [1/138] Blue Serene Backwater Resort...
#   ✓ Got 10 reviews
#
# 🏨 [2/138] SylVan Resort...
#   ✓ Got 10 reviews
#
# 🏨 [3/138] The Crescent Wayanad Heritage Pool Resort...
#   ✓ Got 10 reviews
#
# 🏨 [4/138] PARK RESIDENCY ARCADIA...
#   ✓ Got 10 reviews
#
# 🏨 [5/138] Super Hotel O Thrissur Near Thrissur Medical Colle...
#   ✓ Got 10 reviews
#
# 🏨 [6/138] Hotel Urban Bella...
#   ✓ Got 10 reviews
#
# 🏨 [7/138] Nature Valley Farmhouse Resort by Raarees, Munnar ...
#   ✓ Got 10 reviews
#
# 🏨 [8/138] Royal Plaza Inn by RAK Rooms, Calicut...
#   ✓ Got 10 reviews
#
# 🏨 [9/138] WithInn Hotel - Kannur Airport...
#   ✓ Got 10 reviews
#
# 🏨 [10/138] Ushasree Wayanad Premium Pool Resort by VOYE HOMES...
#   ✓ Got 10 reviews
# 💾 Checkpoint saved: 138 hotels, 100 reviews
# 💾 Saved: 10 hotels, 100 reviews
#
# 🏨 [11/138] The TeaTree Munnar...
#   ✓ Got 10 reviews
#
# 🏨 [12/138] Thekkady Gavi Suites...
#   ✓ Got 10 reviews
#
# 🏨 [13/138] Kovalam Beach House...
#   ✓ Got 10 reviews
#
# 🏨 [14/138] Pugmarks Jungle Resort...
#   ✓ Got 10 reviews
#
# 🏨 [15/138] Viraj Retreat...
#   ✓ Got 8 reviews
#
# 🏨 [16/138] Luxo Kochi...
#   ✓ Got 10 reviews
#
# 🏨 [17/138] Super Hotel O Kunnamangalam Near Bus Stand...
#   ✓ Got 10 reviews
#
# 🏨 [18/138] CONTOUR ISLAND RESORT & SPA , wayanad...
#   ✓ Got 10 reviews
#
# 🏨 [19/138] Daan Inn Infopark, Kakkanad, Kochi...
#   ✓ Got 10 reviews
#
# 🏨 [20/138] Athirappilly Rainland Resort...
#   ✓ Got 10 reviews
# 💾 Checkpoint saved: 138 hotels, 198 reviews
# 💾 Saved: 20 hotels, 198 reviews
#
# 🏨 [21/138] British County Resorts...
#   ✓ Got 10 reviews
#
# 🏨 [22/138] Time Square Boutique Hotel & Spa...
#   ✓ Got 10 reviews
#
# 🏨 [23/138] Niyatma Wayanad Pool Resort by VOYE HOMES - Inside...
#   ✓ Got 10 reviews
#
# 🏨 [24/138] PEARL ROYAL INTERNATIONAL HOTELS & RESORTS PVT LTD...
#   ✓ Got 10 reviews
#
# 🏨 [25/138] Cranganor History Café & Riverside Château...
#   ✓ Got 10 reviews
#
# 🏨 [26/138] The Hive, Wayanad...
#   ✓ Got 10 reviews
#
# 🏨 [27/138] Munnar Tea Estate Cottage and Resort - Away From C...
#   ✓ Got 10 reviews
#
# 🏨 [28/138] ESAA Airport Hotel...
#   ✓ Got 10 reviews
#
# 🏨 [29/138] Wayanad Silverwoods Forest Resort & Spa...
#   ✓ Got 10 reviews
#
# 🏨 [30/138] Misty Range Resorts...
#   ✓ Got 10 reviews
# 💾 Checkpoint saved: 138 hotels, 298 reviews
# 💾 Saved: 30 hotels, 298 reviews
#
# 🏨 [31/138] Orchid Trails Resort...
#   ✓ Got 10 reviews
#
# 🏨 [32/138] Hotel Laals Inn Grand By Jesway Hotels and Resorts...
#   ✓ Got 10 reviews
#
# 🏨 [33/138] Munnar Ice Queen Resorts...
#   ✓ Got 10 reviews
#
# 🏨 [34/138] Le Montfort Resort...
#   ✓ Got 10 reviews
#
# 🏨 [35/138] Collection O EXPRESS SUITES...
#   ✓ Got 10 reviews
#
# 🏨 [36/138] Karapuzha Village Resort...
#   ✓ Got 10 reviews
#
# 🏨 [37/138] SkyLounge Residency...
#   ✓ Got 10 reviews
#
# 🏨 [38/138] Vajra Ayurveda and Yoga Retreat...
#   ✓ Got 10 reviews
#
# 🏨 [39/138] WaterFront by PALMYRA...
#   ✓ Got 10 reviews
#
# 🏨 [40/138] Au Revoir Wellness Resort, Malampuzha...
#   ✓ Got 10 reviews
# 💾 Checkpoint saved: 138 hotels, 398 reviews
# 💾 Saved: 40 hotels, 398 reviews
#
# 🏨 [41/138] Iyer Square...
#   ✓ Got 9 reviews
#
# 🏨 [42/138] Mesteria Inn Wayanad...
#   ✓ Got 4 reviews
#
# 🏨 [43/138] Hotel Wilton...
#   ✓ Got 10 reviews
#
# 🏨 [44/138] The Raarees Mist Resort, Munnar - Nested in Nature...
#   ✓ Got 10 reviews
#
# 🏨 [45/138] 900 Woods Wayanad Eco Resort - A Sprawling Jungle ...
#   ✓ Got 10 reviews
#
# 🏨 [46/138] Distrikt 9...
#   ✓ Got 10 reviews
#
# 🏨 [47/138] Elephant Passage...
#   ✓ Got 10 reviews
#
# 🏨 [48/138] Munkudil Ayurveda & Yoga Retreat...
#   ✓ Got 10 reviews
#
# 🏨 [49/138] Sajjoys...
#   ✓ Got 10 reviews
#
# 🏨 [50/138] Hotel Saffron Wayanad...
#   ✓ Got 10 reviews
# 💾 Checkpoint saved: 138 hotels, 491 reviews
# 💾 Saved: 50 hotels, 491 reviews
#
# 🏨 [51/138] Mount Tales Vagamon...
#   ✓ Got 10 reviews
#
# 🏨 [52/138] Super Hotel O West Hill near Mietra Hospital...
#   ✓ Got 10 reviews
#
# 🏨 [53/138] Hotel Riviera Garden...
#   ✓ Got 10 reviews
#
# 🏨 [54/138] Hotel Arches...
#   ✓ Got 10 reviews
#
# 🏨 [55/138] MoonBasa Boutique Hotel and Spa Infopark , Kakkana...
#   ✓ Got 10 reviews
#
# 🏨 [56/138] Treebo Majestic Retreat...
#   ✓ Got 10 reviews
#
# 🏨 [57/138] O'live Inn Wayanad Apart-Hotels...
#   ✓ Got 3 reviews
#
# 🏨 [58/138] Entire 4 Bedroom Villa in Kannur...
#   ✓ Got 5 reviews
#
# 🏨 [59/138] Rivera Residency Trivandrum...
#   ✓ Got 10 reviews
#
# 🏨 [60/138] Ananda Holiday Home...
#   ✓ Got 7 reviews
# 💾 Checkpoint saved: 138 hotels, 576 reviews
# 💾 Saved: 60 hotels, 576 reviews
#
# 🏨 [61/138] CJ GRANDE by Jesway Hotels & Resorts...
#   ✓ Got 10 reviews
#
# 🏨 [62/138] Hilux Inn...
#   ✓ Got 10 reviews
#
# 🏨 [63/138] The Planet Munnar...
#   ✓ Got 10 reviews
#
# 🏨 [64/138] Niraamaya Wellness Retreats, Surya Samudra, Kovala...
#   ✓ Got 10 reviews
#
# 🏨 [65/138] Beach Paradise Day Cruise Houseboat...
#   ✓ Got 10 reviews
#
# 🏨 [66/138] Itsy Hotels Avani Stays, Vyttila, Kochi...
#   ✓ Got 10 reviews
#
# 🏨 [67/138] Fragrant Nature Kochi - A Five star Classified Hot...
#   ✓ Got 10 reviews
#
# 🏨 [68/138] Marari Villas - Private Pool Villas...
#   ✓ Got 10 reviews
#
# 🏨 [69/138] PRESIDENCY AIRPORT HOTEL...
#   ✓ Got 10 reviews
#
# 🏨 [137/138] Holy Village Homestay...
#   ✓ Got 4 reviews
# 💾 Checkpoint saved: 138 hotels, 670 reviews
#
# ✅ Done! 670 reviews from 70 hotels

# %% [markdown]
# ## 10. View & Export Results

# %%
# View results and export to CSV
if scraped_reviews:
    df = pd.DataFrame(scraped_reviews)

    # Add row numbers
    df.insert(0, "No.", range(1, len(df) + 1))

    # Rename columns to match template
    df = df.rename(
        columns={
            "hotel_name": "Hotel Name",
            "reviewer_name": "Reviewer Name",
            "rating": "Review Rating (1–10)",
            "review_title": "Review Title",
            "review_text": "Review Text",
            "total_review_count": "TOTAL REVIEW COUNT OF HOTEL",
            "star_rating": "HOTEL STAR CLASSIFICATION",
            "overall_rating": "OVERAL HOTEL RATING",
            "sold_out_status": "SOLD OUT STATUS",
        }
    )

    # Save to CSV
    output_file = "kerala_hotels_reviews.csv"
    df.to_csv(output_file, index=False, encoding="utf-8-sig")
    print(f"✅ Saved {len(df)} reviews to {output_file}")

    # Display sample
    display(df.head(20))

    # Stats
    print(f"\nTotal reviews: {len(df)}")
    print(f"Unique hotels: {df['Hotel Name'].nunique()}")
else:
    print("No reviews collected yet. Run the collection cells first.")
# Out:
# ✅ Saved 670 reviews to kerala_hotels_reviews.csv
#     No.                    Hotel Name Reviewer Name Review Rating (1–10)  \
# 0     1  Blue Serene Backwater Resort  Dharmalingam                  6.0
# 1     2  Blue Serene Backwater Resort        Jitesh                  7.0
# 2     3  Blue Serene Backwater Resort        Neelam                  8.0
# 3     4  Blue Serene Backwater Resort             G                  8.0
# 4     5  Blue Serene Backwater Resort     Noordheen                  8.0
# 5     6  Blue Serene Backwater Resort       Sreelal                  7.0
# 6     7  Blue Serene Backwater Resort        Neeraj                  8.0
# 7     8  Blue Serene Backwater Resort        Rajani                  8.0
# 8     9  Blue Serene Backwater Resort       Pradeep                  8.0
# 9    10  Blue Serene Backwater Resort        Loftin                  7.0
# 10   11                 SylVan Resort       Bhavesh                   10
# 11   12                 SylVan Resort       Claudia                   10
# 12   13                 SylVan Resort       Vadiraj                   10
# 13   14                 SylVan Resort         Aruna                   10
# 14   15                 SylVan Resort         Sunil                   10
# 15   16                 SylVan Resort       Sourabh                   10
# 16   17                 SylVan Resort        Ashish                  8.0
# 17   18                 SylVan Resort       Shirish                   10
# 18   19                 SylVan Resort       Tejaswi                  9.0
# 19   20                 SylVan Resort     Raghunath                   10
#
#                                          Review Title  \
# 0                                            Pleasant
# 1                                                Good
# 2                Relaxing Stay at Blue Serene Resorts
# 3             Very clean hotel at excellent location…
# 4                                           Very good
# 5   Can be a really great place with better admini...
# 6                          Excellent value for money.
# 7                                           Very good
# 8                                          Very good.
# 9                       Good rooms. Bad swimming pool
# 10                    Friendly Staff and clean rooms.
# 11                                        Exceptional
# 12                               Very good experience
# 13  A lovely place for the beautiful surroundings ...
# 14                                        Exceptional
# 15                                        Exceptional
# 16                                          Very good
# 17  Close to perfect place for a relaxing 2-3 day ...
# 18                 Great leisure stay.. Full of green
# 19                                                All
#
#                                           Review Text  \
# 0   Food - very tasty and quantity also much bette...
# 1   Ambience and the water body Spa was not functi...
# 2   Blue Serene Resorts offers a delightful stay w...
# 3   Location,cleanliness Catering staff needs more...
# 4                                                Food
# 5   great and quiet location, nice property, view ...
# 6   Great value for money and location by the rive...
# 7   Clean , serene property. Food quality was very...
# 8   Generally very good. Stay, location and the fo...
# 9   Breakfast was very good. Room was neat and cle...
# 10  Large site surrounded by greenery. Clean rooms...
# 11  The location was so beautiful it exceeded our ...
# 12         Need to add some south indian breakfast NA
# 13  A serene property set amidst greenery! Very pe...
# 14                                      yes, ita good
# 15  very good property, very well build, need vehi...
# 16  Everything from location to cleanliness to fri...
# 17  Incredible place. The location is beautiful an...
# 18  Great cozy stay. Bathrooms could have been a l...
# 19                                            All All
#
#    HOTEL STAR CLASSIFICATION OVERAL HOTEL RATING TOTAL REVIEW COUNT OF HOTEL  \
# 0                    10 STAR                 7.3                         100
# 1                    10 STAR                 7.3                         100
# 2                    10 STAR                 7.3                         100
# 3                    10 STAR                 7.3                         100
# 4                    10 STAR                 7.3                         100
# 5                    10 STAR                 7.3                         100
# 6                    10 STAR                 7.3                         100
# 7                    10 STAR                 7.3                         100
# 8                    10 STAR                 7.3                         100
# 9                    10 STAR                 7.3                         100
# 10                                           9.2                         159
# 11                                           9.2                         159
# 12                                           9.2                         159
# 13                                           9.2                         159
# 14                                           9.2                         159
# 15                                           9.2                         159
# 16                                           9.2                         159
# 17                                           9.2                         159
# 18                                           9.2                         159
# 19                                           9.2                         159
#
#    SOLD OUT STATUS
# 0         SOLD OUT
# 1         SOLD OUT
# 2         SOLD OUT
# 3         SOLD OUT
# 4         SOLD OUT
# 5         SOLD OUT
# 6         SOLD OUT
# 7         SOLD OUT
# 8         SOLD OUT
# 9         SOLD OUT
# 10        SOLD OUT
# 11        SOLD OUT
# 12        SOLD OUT
# 13        SOLD OUT
# 14        SOLD OUT
# 15        SOLD OUT
# 16        SOLD OUT
# 17        SOLD OUT
# 18        SOLD OUT
# 19        SOLD OUT
# Total reviews: 670
# Unique hotels: 70
