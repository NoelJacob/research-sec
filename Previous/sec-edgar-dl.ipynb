# %%
# !uv pip install sec-edgar

# %%
import nest_asyncio
from secedgar import FilingType, filings

nest_asyncio.apply()

# %%
filings = filings(
    cik_lookup=["aapl", "fb"],
    filing_type=FilingType.FILING_10K,
    user_agent="Noel Jacob (noeljacob91@gmail.com)",
)

# %%
filings.save("./sec-edgar-data")
# Out:
# /home/noel/Dev/Research/sec/.venv/lib/python3.12/site-packages/secedgar/cik_lookup.py:151: UserWarning: Lookup 'fb' will be skipped.
#                           Found multiple companies matching 'fb':
#                           FB BANCORP
# FB Bancorp
# FB Bancorp, Inc. /MD/SIC: 6036 - SAVINGS INSTITUTIONS, NOT FEDERALLY CHARTERED
# FB CAPITAL MANAGEMENT OF KANSAS INC
# FB CAPITAL TRUST
# FB CorpSIC: 6022 - STATE COMMERCIAL BANKS
# FB Creek Partners LLC
# FB EQUITY SALES CORPORATION OF MICHIGAN
# FB Financial CorpSIC: 6022 - STATE COMMERCIAL BANKS
# Ditto Holdings, Inc.
# FB Flexure LLC
# FB Fund I, a series of Coutre Capital, LP
# FB Gulfdale
# FB HA Holdings LP
# FB Harvest Plaza LP
# FB Hollytree LP
# FB Income Advisor, LLC
# FB Merger Sub
# FB of Long Island LLC
# FB Parent Ltd.
# FB PARTICIPACOES S.A.
# FB PLYMOUTH MEETING LLC
# FB Riverside I, LLC
# FB Riverside II GP, LLC
# FB S. Plains Investment Fund, LLC
# FB Sigma, LLC
# FB Silvercreek LP
# FB Sorrento III, L.L.C.
# ...
